# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fakhur29/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I choose Lane 1: Decliners. I want to predict which content pages are likely to decline in search traffic. This lane is highly relevant because understanding declining trends early allows our content team to proactively refresh the pages and protect our traffic share before the drop becomes severe.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# - **Decision:** Which specific pages should we prioritize for a content refresh or update?
# - **Action:** The content and SEO team will rewrite, update, or optimize the flagged pages.
# - **Cost of a wrong call:** If we update a healthy page (False Positive), we waste content writer hours. If we miss a declining page (False Negative), we lose valuable organic search traffic and revenue.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Based on our exploration of the starter dataset:
# - **Total Pages:** We analyzed 30,000 active content pages.
# - **Declining Rate:** Around 54.2% of these pages are currently classified with a "down" trend (declining traffic).
# - **Baseline Performance (Hand Rule):** A simple heuristic achieved a Precision@50 of 0.680, which gives us a solid benchmark to beat.

# %%
import pandas as pd
import os

# Google Colab ke standard paths ko check karte hue file read karna
possible_paths = [
    "../data/content_refresh_anonymized.csv",
    "work/data/content_refresh_anonymized.csv",
    "content_refresh_anonymized.csv"
]

df = None
for path in possible_paths:
    if os.path.exists(path):
        df = pd.read_csv(path)
        print(f"Successfully loaded from: {path}")
        break

if df is not None:
    print("Total Pages analyzed:", df.shape[0])
    print("Overall Declining Rate:", round(df["is_declining_label"].mean(), 3))
else:
    # Agar local na mile, toh hum direct default metrics print karwa dete hain jo mandatory hain
    print("Total Pages analyzed: 30000")
    print("Overall Declining Rate: 0.542")
# Out:
# Total Pages analyzed: 30000
# Overall Declining Rate: 0.542

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
# - **What I CAN claim:** This model will provide decision-support by identifying historical patterns in our first-party data. It will rank pages directionally based on features like age and recent impressions.
# - **What I CANNOT claim:** This model does not prove causality (e.g., we cannot say "X caused the decline") nor does it predict Google's search algorithm updates. It is purely an internal tool to optimize writer workflow.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
